# %%
""" Problem 8.1.3 """

import matplotlib.pyplot as plt
import numpy as np
from scipy import signal as sig
from math import pi, exp, cos, sin, log, log10, sqrt

# %%
wp = 0.01
Hp2 = (.8)**2

np = log10(1/Hp2 - 1)/(2*log10(wp))
print('np =', np)
# Out:
# np = 0.06246936830415002
