# %%
""" Problem 7.6.2 """

import matplotlib.pyplot as plt
import numpy as np
from scipy import signal as sig
from math import pi, exp, cos, sin, log, sqrt
from control import margin
from control import tf

# %%
K = 1
n1 = [0, 0, 6000]
d1 = [1, 20, 0]

n2 = [0, 0, 1]
d2 = [0, 0, 1]

n12 = K*np.convolve(n1,n2)
d12 = np.convolve(d1,d2)

num = n12
den = d12

w = np.linspace(0.1,100,num=1000)
system = sig.lti(num,den)
w, Hmag, Hphase = sig.bode(system,w)
gm, pm, wg, wp = margin(Hmag,Hphase,w)

plt.subplot(211)
plt.semilogx(w,Hmag,'k')
plt.axis([ .1, 1e2, -20, 80])
plt.ylabel('|H| dB',size = 12)
plt.text(.3,0,'$\omega$p = {}'.format(round(wp,1)),fontsize=12)
plt.title('Bode Comp')
plt.grid(which='both')

for n in range(100):
    if Hphase[n] > 0:
        Hphase[n] = Hphase[n] - 360

plt.subplot(212)
plt.semilogx(w,Hphase,'k')
plt.axis([ .1, 1e2, -180,0])
plt.yticks([-180,-90,0])
plt.xlabel('$\omega$ (rad/s)')
plt.ylabel('Phase (degrees)',size=12)
plt.text(.3,-150,'pm = {}'.format(round(pm,0)),fontsize=12)
plt.grid(which='both')
plt.savefig('H_bode.png',dpi=300)
plt.show()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:35: SyntaxWarning: invalid escape sequence '\o'
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:35: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_60932\4178018766.py:23: SyntaxWarning: invalid escape sequence '\o'
#   plt.text(.3,0,'$\omega$p = {}'.format(round(wp,1)),fontsize=12)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_60932\4178018766.py:35: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega$ (rad/s)')
# C:\Users\Gabriel\anaconda3\Lib\site-packages\scipy\signal\_ltisys.py:600: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   self.num, self.den = normalize(*system)

# %%
""" Phase Lead Calculations """

p_m = 34 *(np.pi/180)
a = (1+np.sin(p_m))/(1-np.sin(p_m))
w_m = -10*np.log10(a)
print("w_m =", w_m)
# Out:
# w_m = -5.4865127187792115

# %%
# Use this function to find corresponding w
center_freq = 100 #rad/s
w_guess = np.interp(center_freq, w, Hmag)
print(w_m, "=", w_guess)
# Out:
# -5.4865127187792115 = -4.607308385314931

# %%
w_p = np.sqrt(a)*center_freq
w_z = center_freq/np.sqrt(a)
print("w_m =", center_freq, "rad/s")
print("w_p =", w_p, "rad/s")
print("w_z =", w_z, "rad/s")
# Out:
# w_m = 100 rad/s
# w_p = 188.07264653463324 rad/s
# w_z = 53.170943166147865 rad/s

# %%
""" Phase Lead Implementation """

K = w_p/w_z
n1 = [0, 0, 6000]
d1 = [1, 20, 0]

n2 = [0, 1, w_z]
d2 = [0, 1, w_p]

n12 = K*np.convolve(n1,n2)
d12 = np.convolve(d1,d2)

num = n12
den = d12

w = np.linspace(0.1,100,num=1000)
system = sig.lti(num,den)
w, Hmag, Hphase = sig.bode(system,w)
gm, pm, wg, wp = margin(Hmag,Hphase,w)

plt.subplot(211)
plt.semilogx(w,Hmag,'k')
plt.axis([ .1, 1e2, -20, 80])
plt.ylabel('|H| dB',size = 12)
plt.text(.3,0,'$\omega$p = {}'.format(round(wp,1)),fontsize=12)
plt.title('Bode Comp')
plt.grid(which='both')

for n in range(100):
    if Hphase[n] > 0:
        Hphase[n] = Hphase[n] - 360

plt.subplot(212)
plt.semilogx(w,Hphase,'k')
plt.axis([ .1, 1e2, -180,0])
plt.yticks([-180,-90,0])
plt.xlabel('$\omega$ (rad/s)')
plt.ylabel('Phase (degrees)',size=12)
plt.text(.3,-150,'pm = {}'.format(round(pm,0)),fontsize=12)
plt.grid(which='both')
plt.savefig('H_bode.png',dpi=300)
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\o'
# <>:37: SyntaxWarning: invalid escape sequence '\o'
# <>:25: SyntaxWarning: invalid escape sequence '\o'
# <>:37: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_60932\1133718377.py:25: SyntaxWarning: invalid escape sequence '\o'
#   plt.text(.3,0,'$\omega$p = {}'.format(round(wp,1)),fontsize=12)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_60932\1133718377.py:37: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega$ (rad/s)')
