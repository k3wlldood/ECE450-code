# %%
""" Exam 1 """

import matplotlib.pyplot as plt
import numpy as np
from math import exp, cos, sin, log
from math import pi, sqrt, exp, cos, sin
from cmath import exp
from scipy import linalg
from scipy.linalg import expm

# %%
""" Matrix Definitions """

dt = 0.1 # Change 'dt' between 0.1 and 0.3
NN = int(10/dt)
TT = np.arange(0, dt*NN, dt)
time1 = np.zeros(NN)
time2 = np.zeros(NN)
time3 = np.zeros(NN)
time4 = np.zeros(NN)
time5 = np.zeros(NN)
nsteps = NN

A = np.matrix('0 1 0 0 0; -10 -5 1 0 0; 0 0 -10 -3 1; 0 0 0 0 1; 0 0 0 5 -2')
B = np.matrix('0; 0; 0; 0; 1')
C = np.matrix('1 0 0 -3 1')
x = np.matrix('0; 0; 0; 0; 0')
x[0] = 2
x[1] = 0
x[2] = 0
x[3] = 0
x[4] = 0

""" Forcing Functions """

f = np.zeros(NN)

for n in range(int(2/dt), int(4/dt)):
    f[n] = 1

""" State Space Response """

y1 = np.zeros(NN)

for i in range(nsteps):    
    time1[i] = x[0]
    time2[i] = x[1]
    time3[i] = x[2]
    time4[i] = x[3]
    time5[i] = x[4]

    x = x + dt*A*x + dt*B*f[i]

    y1[i] = (C*x)[0,0]

""" State Transition Response """

F = expm(A*dt)

Ainv = np.linalg.inv(A)
I = np.eye(5)
G = (F-I)*Ainv*B
wtime1 = np.zeros(NN)
wtime2 = np.zeros(NN)
wtime3 = np.zeros(NN)
wtime4 = np.zeros(NN)
wtime5 = np.zeros(NN)
y2 = np.zeros(NN)

w = np.matrix('0;0;0;0;0')
w[0] = 2
w[1] = 0
w[2] = 0
w[3] = 0
w[4] = 0

for i in range(nsteps):
    wtime1[i] = w[0]
    wtime2[i] = w[1]
    wtime3[i] = w[2]
    wtime4[i] = w[3]
    wtime5[i] = w[4]

    w = F*w + G*f[i]

    y2[i] = (C*w)[0,0]
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:35: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   time1[i] = x[0]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   time2[i] = x[1]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   time3[i] = x[2]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   time4[i] = x[3]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:39: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   time5[i] = x[4]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:67: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   wtime1[i] = w[0]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:68: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   wtime2[i] = w[1]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:69: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   wtime3[i] = w[2]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:70: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   wtime4[i] = w[3]
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_3876\2919030338.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   wtime5[i] = w[4]

# %%
plt.figure(figsize = (8,9))
plt.subplot(311)
plt.title('Forcing Functions')
plt.plot(TT, f, 'k', label = 'F')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()


plt.figure(figsize = (8,9))
plt.subplot(311)
plt.plot(TT, time1, 'k', label = 'x1')
plt.plot(TT, time2, 'k-.', label = 'x2')
plt.plot(TT, time3, 'k--', label = 'x3')
plt.legend()
plt.grid()
plt.title('State Space Response')

plt.subplot(312)
plt.plot(TT, time4, 'k-.', label = 'x4')
plt.plot(TT, time5, 'k', label = 'x5')
plt.legend()
plt.grid()

plt.subplot(313)
plt.plot(TT, y1, 'k', label = 'y')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()


plt.figure(figsize = (8,9))
plt.subplot(311)
plt.plot(TT, wtime1, 'k', label = 'w1')
plt.plot(TT, wtime2, 'k-.', label = 'w2')
plt.plot(TT, wtime3, 'k--', label = 'w3')
plt.legend()
plt.grid()
plt.title('State Transition Response')

plt.subplot(312)
plt.plot(TT, wtime4, 'k-.', label = 'w4')
plt.plot(TT, wtime5, 'k', label = 'w5')
plt.legend()
plt.grid()

plt.subplot(313)
plt.plot(TT, y2, 'k', label = 'y')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
